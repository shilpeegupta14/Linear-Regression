# %%
# !pip install -q sklearn

# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
from sklearn.linear_model import LinearRegression
from pandas import *

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ea1935e6-3628-4de6-8714-6703319ff422" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea1935e6-3628-4de6-8714-6703319ff422">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset.csv to dataset.csv

# %%
df=pd.read_csv("dataset.csv")

# %%
# %matplotlib inline
plt.xlabel("possible values of x")
plt.ylabel("possible values of y")
plt.scatter(df.potato_kg,df.price)

# %%
x=[['potato_kg']]
y=df['price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.potato_kg, df.price, test_size=0.2)

# %%
x_train
# Out:
# 7     8
# 1     2
# 3     4
# 4     5
# 8     9
# 6     7
# 0     1
# 9    10
# Name: potato_kg, dtype: int64

# %%
x_test
# Out:
# 2    3
# 5    6
# Name: potato_kg, dtype: int64

# %%
y_train
# Out:
# 7    100
# 1     20
# 3     40
# 4     55
# 8    115
# 6     90
# 0     10
# 9    120
# Name: price, dtype: int64

# %%
y_test
# Out:
# 2    25
# 5    75
# Name: price, dtype: int64

# %%
x=df.iloc[:, 0].values
y=df.iloc[:, 1].values

# %%
X = df[['potato_kg']]

# %%
y = df['price']

# %%
x_train.values.reshape(4,2)
# Out:
# array([[ 8,  2],
#        [ 4,  5],
#        [ 9,  7],
#        [ 1, 10]])
