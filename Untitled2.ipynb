# %% [markdown]
# <a href="https://colab.research.google.com/github/shilpeegupta14/Linear-Regression/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
from sklearn.linear_model import LinearRegression
from pandas import *

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5911ebe6-2324-4472-9737-31368977c29c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5911ebe6-2324-4472-9737-31368977c29c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train.csv to train.csv

# %%
df=pd.read_csv("test.csv")

# %%
df=pd.read_csv("train.csv")

# %%
X = df.iloc[:, :-1].values
Y = df.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 1/3, random_state = 0)

# %%
# %matplotlib inline
plt.xlabel("possible values of x")
plt.ylabel("possible values of y")
plt.scatter(df.x,df.y)

# %%
x=[['x']]
y=df['y']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.x, df.y, test_size=0.2)

# %%
x_train
# Out:
# 73     58.0
# 127     3.0
# 556    21.0
# 274    48.0
# 190    61.0
#        ...
# 635    63.0
# 519    85.0
# 359    13.0
# 221    74.0
# 639     1.0
# Name: x, Length: 560, dtype: float64

# %%
x_test
# Out:
# 138    95.0
# 117    26.0
# 141    80.0
# 289    41.0
# 448    47.0
#        ...
# 410    99.0
# 629    16.0
# 497    61.0
# 375    92.0
# 368    88.0
# Name: x, Length: 140, dtype: float64

# %%
y_train
# Out:
# 73     57.077484
# 127     3.574662
# 556    22.510166
# 274    47.781652
# 190    61.145685
#          ...
# 635    63.673482
# 519    82.476835
# 359    10.285748
# 221    72.635670
# 639     5.809947
# Name: y, Length: 560, dtype: float64

# %%
y_test
# Out:
# 138    94.088534
# 117    28.900558
# 141    75.241484
# 289    41.214699
# 448    46.066295
#          ...
# 410    94.970688
# 629    17.034020
# 497    60.388231
# 375    91.850911
# 368    90.579987
# Name: y, Length: 140, dtype: float64

# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
boston = load_boston()
X = boston.data
Y = boston.target

lineReg = LinearRegression()
lineReg.fit(X, Y)
lineReg.score(X, Y)
# Out:
# 0.7406426641094095

# %%
x_train = np.array(x_train)
x_test = np.array(x_train)

x_train = np.reshape(x_train)
x_test = np.reshape(x_test)

lineReg.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-66e217fe0eb3> in <module>()
#       2 x_test = np.array(x_train)
#       3
# ----> 4 x_train = np.reshape(x_train,(2404,28,224,224,3))
#       5 x_test = np.reshape(x_test,(601,28,224,224,3))
#       6
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ...

# %%
x_train_reshaped=np.reshape(x_train,(60000, 28, 28))
x_test_reshaped=np.reshape(x_test,(10000, 28, 28))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-76dc8064a4ae> in <module>()
# ----> 1 x_train_reshaped=np.reshape(x_train,(60000, 28, 28))
#       2 x_test_reshaped=np.reshape(x_test,(10000, 28, 28))
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ...
